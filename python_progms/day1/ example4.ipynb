# %%
var1 = 10 
print(type(var1))
# Out:
# <class 'int'>

# %%
var1 = 24.5
print(type(var1))
# Out:
# <class 'float'>

# %%
var1 = "hello"
print(type(var1))
# Out:
# <class 'str'>

# %%
var1 = (10, "hi" , 48, "no")
print(type(var1))
# Out:
# <class 'tuple'>

# %%
var1 = [10, "hi" , 48, "no"]
print(type(var1))
# Out:
# <class 'list'>

# %%
var1= { 'os' : 'windows' , 'db' : ' mysql' , 'lang' : 'python'}
print(type(var1))
# Out:
# <class 'dict'>

# %%
var1 = {10,78 , 48, 32, 56, 21 } #set is unordered and non duplicate , doesnot have index
print(type(var1))
# Out:
# <class 'set'>

# %%
var1 = True
print(type(var1))
# Out:
# <class 'bool'>
