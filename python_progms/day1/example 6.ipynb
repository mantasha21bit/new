# %%
# operator + , - , *, / , //
print(15/4)
print(15//4)
# Out:
# 3.75
# 3

# %%
print (5 & 6)
# binary operation 
#5= 101 , 6=110
# Out:
# 4

# %%
# membership operator
# in operator
s1 = "helli"
if 'e' in s1:
    print("found ")
else :
    print("not found")

if 'm' in s1:
    print("found ")
else :
    print("not found")
# Out:
# found
# not found

# %%
a=10 

if type(a) is int :
    print("is integer")
else :
    print ("not integer")

a="10"
if type(a) is int :
    print("is integer")
else :
    print ("not integer")
# Out:
# is integer
# not integer
